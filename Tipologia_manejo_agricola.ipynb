# %% [markdown]
# # Una tipología de manejo agrícola para los municipios de México

# %% [markdown]
# El primer objetivo del proyecto consistió en construir una tipología de prácticas de manejo agrícola para los municipios de México y para los de la Península de Yucatán. La tipología agrupa a los municipios de acuerdo a su similitud en prácticas de manejo y, por tanto, también permite distinguir aquellos con manejos contrastantes. Aquí documento la construcción de esta tipología a partir de datos de INEGI.

# %% [markdown]
# ## Datos
#
# Se utilizarán datos del Censo Agrícola, Ganadero y Forestal 2007 (INEGI), a nivel municipal, que corresponden a alrededor de 2400 municipios. En particular se considerarán las siguientes variables (todas son de tipo numérico, continuas):
#
# * **Uso de suelo.** Porcentaje de la superficie del municipio dedicada a 1) labor agrícola y 2) bosque o selva.
# * **Tipo de tracción.** Porcentaje de las unidades de producción del municipio que emplean sólo tracción mecánica para realizar las labores agrícolas.
# * **Origen del agua.** Porcentaje de la superficie agrícola del municipio en la que se practica agricultura de temporal.
# * **Insumos.** Porcentaje de la superficie agrícola del municipio que emplea 1) herbicidas químicos y 2) insecticidas químicos.
#
# Previamente se estandarizó el formato de los datos, se quitaron valores nulos y se integraron las variables a utilizar en un mismo archivo `censo.csv`.

# %%
# bibliotecas a utilizar
import pandas, numpy, seaborn
from matplotlib import pyplot

# %%
# leer los datos
datos = pandas.read_csv('./resultados/datos_procesados/censo.csv', encoding ='ISO-8859-1')
datos = datos.set_index('Clave')

# %%
datos[['Entidad y municipio', 'Entidad', '% Temporal', '% Mecánica', 
       '% labor agricola', '% bosque', '% Herbicidas químicos', 
       '% Insecticidas químicos']].head()
# Out:
#        Entidad y municipio         Entidad  % Temporal  % Mecánica  \
# Clave
# 01_001      AGUASCALIENTES  AGUASCALIENTES   75.123727   83.413297
# 01_002            ASIENTOS  AGUASCALIENTES   77.939970   79.576299
# 01_003            CALVILLO  AGUASCALIENTES   59.930021   38.037634
# 01_004               COSÍO  AGUASCALIENTES   47.511173   91.229743
# 01_005         JESÚS MARÍA  AGUASCALIENTES   72.548701   80.868167
#
#         % labor agricola  % bosque  % Herbicidas químicos  \
# Clave
# 01_001         52.676031  0.044765              20.376084
# 01_002         80.546052  0.101570              12.520469
# 01_003         24.321383  0.650017              14.951300
# 01_004         77.868016  0.025051              19.282536
# 01_005         33.136668  0.362998              33.637145
#
#         % Insecticidas químicos
# Clave
# 01_001                 6.765960
# 01_002                 4.501609
# 01_003                 7.547488
# 01_004                 7.912925
# 01_005                 7.005523

# %% [markdown]
# ## Gráficas
#
# Las siguientes gráficas de dispersión muestran un panorama general de la distribución de las variables por estado (donde cada punto representa un municipio).

# %%
# formato general de las gráficas
# %matplotlib inline
seaborn.set_style('whitegrid')
pyplot.rcParams['axes.labelsize'] = 14
pyplot.rcParams['ytick.labelsize'] = 12

# etiquetas paras las gráficas
estados = ['AGU', 'BCN', 'BCS', 'CAM', 'COA',
           'COL', 'CHP', 'CHH','CMX', 'DUR',
          'GUA', 'GRO', 'HID', 'JAL', 'MEX',
          'MIC', 'MOR', 'NAY', 'NLE', 'OAX',
          'PUE', 'QUE', 'ROO', 'SLP', 'SIN',
          'SON', 'TAB', 'TAM', 'TLA', 'VER', 
           'YUC', 'ZAC']

# %% [markdown]
# ### Riego

# %%
pyplot.figure(figsize=(11, 5))
seaborn.stripplot(x='Entidad', y='% Temporal', data=datos, jitter=True, 
                  alpha=0.5, s=8)
locs = pyplot.xticks()[0]
pyplot.xticks(locs, estados, rotation=45)
pyplot.ylim(-1, 102)
pyplot.ylabel('Superficie con \n agricultura de temporal [%]')
pyplot.tight_layout()

# %% [markdown]
# ### Insumos

# %%
pyplot.figure(figsize=(11, 5))
seaborn.stripplot(x='Entidad', y='% Herbicidas químicos', data=datos, 
                  jitter=True, alpha=0.5, s=8)
locs = pyplot.xticks()[0]
pyplot.xticks(locs, estados, rotation=45)
pyplot.ylim(-1, 102)
pyplot.ylabel('Superficie con \n herbicidas químicos [%]')
pyplot.tight_layout()

# %%
pyplot.figure(figsize=(11, 5))
seaborn.stripplot(x='Entidad', y='% Insecticidas químicos', data=datos, 
                  jitter=True, alpha=0.5, s=8)
locs = pyplot.xticks()[0]
pyplot.xticks(locs, estados, rotation=45)
pyplot.ylim(-1, 102)
pyplot.ylabel('Superficie con \n insecticidas químicos [%]')
pyplot.tight_layout()

# %% [markdown]
# ### Uso de suelo

# %%
pyplot.figure(figsize=(11, 5))
seaborn.stripplot(x='Entidad', y='% labor agricola', data=datos, 
                  jitter=True, alpha=0.5, s=8)
locs = pyplot.xticks()[0]
pyplot.xticks(locs, estados, rotation=45)
pyplot.ylim(-1, 102)
pyplot.ylabel('Superficie dedicada a \n labor agrícola [%]')
pyplot.tight_layout()

# %% [markdown]
# ### Tracción

# %%
pyplot.figure(figsize=(11, 5))
seaborn.stripplot(x='Entidad', y='% Mecánica', data=datos, 
                  jitter=True, alpha=0.5, s=8)
locs = pyplot.xticks()[0]
pyplot.xticks(locs, estados, rotation=45)
pyplot.ylim(-1, 102)
pyplot.ylabel('Unidades de producción con \n tracción mecánica [%]')
pyplot.tight_layout()

# %% [markdown]
# ## Tipología nacional

# %% [markdown]
# Se realizó un análisis de componentes principales para identificar las variables que permitieran distinguir la mayor variación entre los municipios y posteriormente se realizó un agrupamiento de los municipios con el algoritmo k-means. Me baso en https://jakevdp.github.io/PythonDataScienceHandbook/05.09-principal-component-analysis.html y en https://jakevdp.github.io/PythonDataScienceHandbook/05.11-k-means.html.

# %% [markdown]
# ### Análisis de componentes principales

# %%
# funciones
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
# definir semilla para la reproducibilidad de los resultados
numpy.random.seed(170)

# %%
# análisis de componentes principales
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(datos[['% Temporal', '% Mecánica', 
                                        '% labor agricola', '% bosque',
                                        '% Herbicidas químicos', 
                                        '% Insecticidas químicos']])

# %%
componentes = pandas.DataFrame(pca.components_.T, index=['% Temporal', '% Mecánica', 
                                                         '% labor agricola', '% bosque',
                                                         '% Herbicidas químicos', 
                                                         '% Insecticidas químicos'])
componentes
# Out:
#                                 0         1
# % Temporal              -0.388399 -0.028287
# % Mecánica               0.781127  0.074427
# % labor agricola        -0.268198  0.900715
# % bosque                -0.002422 -0.057708
# % Herbicidas químicos    0.325058  0.357280
# % Insecticidas químicos  0.247768  0.226704

# %%
# varianza explicada por cada componente
pca.explained_variance_ratio_
# Out:
# array([0.48645058, 0.24418356])

# %% [markdown]
# Se eligieron dos componentes para el PCA. Se encontró que el primero está asociado con las variables `Agricultura de temporal` y `Tracción mecánica`; en cambio, el segundo está asociado principalmente con la variable `Área de labor agrícola`. La varianza explicada por estos componentes es del 49% y 24%, respectivamente.

# %% [markdown]
# ### Agrupamiento con k-means

# %% [markdown]
# Se eligió un parámetro de `k=4` para el agrupamiento de los datos, esto es el número de grupos en los que se quiere agrupar los datos. Con este valor los datos se agrupan en cuadrantes que representan manejos contrastantes, pero como se trata de un parámetro arbitrario se pueden explorar otros agrupamientos.

# %%
# agrupamiento con k-means
kmeans = KMeans(n_clusters = 4)
kmeans.fit(reduced_data)
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# %% [markdown]
# En la siguiente gráfica se muestran los datos reducidos por el PCA y agrupados con el algoritmo de k-means. El *eje x* representa el PC1, es decir, en esta dimensión los valores cambian de gran porcentaje de tracción manual y agricultura de temporal hacia un mayor porcentaje de tracción mecánica y agricultura de riego. Entonces este eje puede interpretarse como un gradiente de intensificación de las actividades agrícolas. En cambio, el *eje y* representa el PC2, y aquí los valores cambian principalmente de poca a mucha superficie agrícola.

# %%
# definir los colores de la tipología
import matplotlib.colors

gold = matplotlib.colors.to_rgba('Gold')
green = matplotlib.colors.to_rgba('SeaGreen')
purple = matplotlib.colors.to_rgba('Indigo')
blue = matplotlib.colors.to_rgba('RoyalBlue')

mis_colores = matplotlib.colors.ListedColormap([gold, blue, purple, green],
                                               'mis_colores')

# %%
fig = pyplot.figure()
pyplot.scatter(reduced_data[:, 0], reduced_data[:, 1], c=labels, s=40, 
               cmap=mis_colores, alpha=0.5, vmin = 0, vmax=3)
pyplot.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.5);
pyplot.xlabel('Componente 1 \n (intensificación)')
pyplot.ylabel('Componente 2 \n (área agríola)')

pyplot.tight_layout()
pyplot.savefig('./resultados/figuras/tipologia_nacional.png', dpi=300)

# %%
# agregar las etiquetas y los valores de pca a la tabla de datos
datos['labels'] = labels
datos['pca1'] = reduced_data[:, 0]
datos['pca2'] = reduced_data[:, 1]

# %% [markdown]
# Por ejemplo, el municipio Peto, en Yucatán está ubicado en el cuadrante superior izquierdo (grupo azul) porque contiene un bajo porcentaje de tracción mecánica (1.5%), mucha superficie con agricultura de temporal (97%) y mucha superficie agrícola (70%):

# %%
datos.loc['31_058']
# Out:
# Entidad y municipio            PETO
# Entidad                     YUCATÁN
# % Mecánica                  1.51106
# % Temporal                  98.6776
# % Herbicidas químicos      0.835941
# % Insecticidas químicos    0.562664
# % labor agricola            70.5016
# % bosque                      2.386
# labels                            1
# pca1                       -40.7867
# pca2                        8.75305
# Name: 31_058, dtype: object

# %% [markdown]
# **Nota:** las etiquetas de los cuadrantes que resultan del agrupamiento son:
#
#  1  |  0
# ----|-----
#  3  |  2

# %%
# guardar datos con la información del pca y el agrupamiento
# datos.to_csv('./resultados/datos_procesados/tipologia_nacional.csv', encoding ='ISO-8859-1')

# %% [markdown]
# Las variables elegidas permitieron clasificar a los municipios de acuerdo a su similitud en prácticas de manejo agrícola. A partir de este agrupamiento se pueden seleccionar grupos de municipios que tengan manejos contrastantes, por ejemplo, municipios agrupados en esquinas opuestas del cuadrante o se pueden comparar de forma sistemática las prácticas de manejo entre municipios.

# %% [markdown]
# ## Tipología regional

# %% [markdown]
# También se construyó una tipología de manejo para los municipios de la Península de Yucatán, siguiendo la metodología anterior.

# %%
datos_peninsula = datos.loc[(datos['Entidad'] == 'QUINTANA ROO') | 
          (datos['Entidad'] == 'CAMPECHE') | 
          (datos['Entidad'] == 'YUCATÁN'), :].copy()

# %%
# análisis de componentes principales
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(datos_peninsula[['% Temporal', '% Mecánica', 
                                        '% labor agricola', '% bosque',
                                        '% Herbicidas químicos', 
                                        '% Insecticidas químicos']])

# %%
componentes = pandas.DataFrame(pca.components_.T, index=['% Temporal', '% Mecánica', 
                                        '% labor agricola', '% bosque',
                                        '% Herbicidas químicos', 
                                        '% Insecticidas químicos'])
componentes
# Out:
#                                 0         1
# % Temporal               0.445271 -0.614278
# % Mecánica               0.467864  0.581704
# % labor agricola         0.670825 -0.251229
# % bosque                 0.035262 -0.016798
# % Herbicidas químicos    0.343990  0.445035
# % Insecticidas químicos  0.115143  0.151095

# %%
# varianza explicada por cada componente
pca.explained_variance_ratio_
# Out:
# array([0.44982917, 0.27980292])

# %% [markdown]
# En este caso, los datos reducidos se agruparon en tres grupos que representan manejos contrastantes.

# %%
# agrupamiento con k-means
kmeans = KMeans(n_clusters = 3)
kmeans.fit(reduced_data)
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# %% [markdown]
# En la siguiente gráfica se muestran los datos reducidos por el PCA y agrupados con el algoritmo de k-means. A diferencia de la tipología nacional, aquí el *eje x* (PCA1) está asociado a la superficie agrícola, mientras que el *eje y* (PCA2) está asociado a un gradiente de intensificación.

# %%
fig = pyplot.figure(figsize=(7, 5))
pyplot.scatter(reduced_data[:, 0], reduced_data[:, 1], c=labels, s=80, cmap='viridis', alpha=0.5)
pyplot.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.5);
#pyplot.xlim(-130, 60)
#pyplot.ylim(-100, 60)
pyplot.xlabel('Componente 1 \n (área agrícola)')
pyplot.ylabel('Componente 2 \n (temporal, tracción mecánica)')

pyplot.tight_layout()
pyplot.savefig('./resultados/figuras/tipologia_regional.png', dpi=300)

# %%
datos_peninsula.loc[:, 'labels'] = labels
datos_peninsula.loc[:, 'pca1'] = reduced_data[:, 0]
datos_peninsula.loc[:, 'pca2'] = reduced_data[:, 1]

# %% [markdown]
# Nota: las etiquetas por posición del centroide en el *eje x* son 2, 0, 1.

# %% [markdown]
# Aquí se muestra de nuevo el municipio Peto en Yucatán, pero ahora con los valores de la tipología regional.

# %%
datos_peninsula.loc['31_058']
# Out:
# Entidad y municipio            PETO
# Entidad                     YUCATÁN
# % Mecánica                  1.51106
# % Temporal                  98.6776
# % Herbicidas químicos      0.835941
# % Insecticidas químicos    0.562664
# % labor agricola            70.5016
# % bosque                      2.386
# labels                            0
# pca1                        29.0437
# pca2                       -20.9669
# Name: 31_058, dtype: object

# %%
# guardar datos con la información del pca y el agrupamiento
# datos_peninsula.to_csv('./resultados/datos_procesados/tipologia_peninsula.csv', encoding ='ISO-8859-1')

# %% [markdown]
# ## Mapas

# %% [markdown]
# Municipios coloreados de acuerdo a mi tipología nacional.

# %%
import geopandas

# %%
estados = geopandas.read_file('./datos/estados/estados_2010.shp', encoding = 'UTF-8')

# %%
municipios = geopandas.read_file('./datos/municipios/municipios_2010.shp', encoding = 'UTF-8')

# %%
municipios.head()
# Out:
#    OBJECTID          AREA  PERIMETER CVE_ENT CVE_MUN   NOM_MUN MUN_OFICIA  \
# 0         1  1.250860e+09  184387.00      02     004   Tijuana      02004
# 1         2  2.724360e+09  220197.00      02     003    Tecate      02003
# 2         3  1.470700e+10  648414.00      02     002  Mexicali      02002
# 3         4  3.705380e+05    3781.82    None    None      None       None
# 4         5  8.097260e+04    2357.91    None    None      None       None
#
#    COV_  COV_ID   CAPITAL          NOM_ENT  \
# 0   2.0     1.0  Mexicali  Baja California
# 1   3.0     2.0  Mexicali  Baja California
# 2   4.0     3.0  Mexicali  Baja California
# 3   5.0     4.0      None             None
# 4   6.0     5.0      None             None
#
#                                             geometry
# 0  POLYGON ((-116.6908195516124 32.57094487736364...
# 1  POLYGON ((-115.8792952720664 32.63608030168875...
# 2  POLYGON ((-114.8135730109702 32.49391286577542...
# 3  POLYGON ((-117.2989432790834 32.44552758540202...
# 4  POLYGON ((-117.2597785821449 32.41888515894957...

# %%
municipios['Clave'] = municipios['CVE_ENT'] + '_' + municipios['CVE_MUN']

# %%
# drop nans from municipios
municipios = municipios.loc[municipios['CVE_ENT'].notnull()]
municipios = municipios.set_index('Clave')

# %%
# drop duplicate index entries
municipios = municipios[~municipios.index.duplicated(keep='first')]

# %%
municipios.head()
# Out:
#         OBJECTID          AREA  PERIMETER CVE_ENT CVE_MUN  \
# Clave
# 02_004         1  1.250860e+09   184387.0      02     004
# 02_003         2  2.724360e+09   220197.0      02     003
# 02_002         3  1.470700e+10   648414.0      02     002
# 02_005         7  5.061130e+08   138347.0      02     005
# 26_055         8  8.961360e+09   529502.0      26     055
#
#                       NOM_MUN MUN_OFICIA  COV_  COV_ID     CAPITAL  \
# Clave
# 02_004                Tijuana      02004   2.0     1.0    Mexicali
# 02_003                 Tecate      02003   3.0     2.0    Mexicali
# 02_002               Mexicali      02002   4.0     3.0    Mexicali
# 02_005     Playas de Rosarito      02005   8.0     7.0    Mexicali
# 26_055  San Luis Río Colorado      26055   9.0     8.0  Hermosillo
#
#                 NOM_ENT                                           geometry
# Clave
# 02_004  Baja California  POLYGON ((-116.6908195516124 32.57094487736364...
# 02_003  Baja California  POLYGON ((-115.8792952720664 32.63608030168875...
# 02_002  Baja California  POLYGON ((-114.8135730109702 32.49391286577542...
# 02_005  Baja California  POLYGON ((-116.6759983915045 32.1852186665698,...
# 26_055           Sonora  POLYGON ((-114.8135730109702 32.49391286577542...

# %%
municipios.index.is_unique
# Out:
# True

# %%
# join municipios and tipologia 
result = pandas.concat([datos, municipios], axis=1, join='inner')
result.head()

# turn into a geopandas dataframe
result = geopandas.GeoDataFrame(result, crs = municipios.crs, geometry = 'geometry')

# %%
type(result)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# graficar
fig, ax = pyplot.subplots(figsize = (20, 12))
estados.plot(ax = ax, facecolor = 'none', edgecolor = 'k', lw = 1)
result.plot('labels', ax = ax, cmap=mis_colores, vmin= 0, vmax = 3, alpha = 0.7)
pyplot.savefig('./resultados/figuras/mapa_tipologia.png', dpi=300)

# %%
# graficar el gradiente intensificación
fig, ax = pyplot.subplots(figsize = (40, 24))
estados.plot(ax = ax, facecolor = 'none', edgecolor = 'k', lw = 1)
result.plot('pca1', ax = ax, legend=True, cmap='viridis', alpha = 0.8)
ax.set_title('Gradiente de intensificación (PCA1).', size=37, loc='left')
pyplot.savefig('.\mapa_pca1.png', dpi=300)
# Out:
# Text(0.0, 1, 'Gradiente de intensificación (PCA1).')
